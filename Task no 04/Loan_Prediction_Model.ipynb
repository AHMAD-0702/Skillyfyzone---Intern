# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv("D:\Skillify Zone Intern\Task no 04\Loan Prediction.csv")

df = df.drop('Loan_ID', axis=1)

categorical = df.select_dtypes(include='object').columns
numerical = df.select_dtypes(exclude='object').columns

cat_imputer = SimpleImputer(strategy='most_frequent')
num_imputer = SimpleImputer(strategy='mean')

df[categorical] = cat_imputer.fit_transform(df[categorical])
df[numerical] = num_imputer.fit_transform(df[numerical])

encoder = LabelEncoder()
for col in categorical:
    df[col] = encoder.fit_transform(df[col])

print(df.head())
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        1           0          0              0           5720.0
# 1       1        1           1          0              0           3076.0
# 2       1        1           2          0              0           5000.0
# 3       1        1           2          0              0           2340.0
# 4       1        0           0          1              0           3276.0
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       110.0             360.0        1.000000
# 1             1500.0       126.0             360.0        1.000000
# 2             1800.0       208.0             360.0        1.000000
# 3             2546.0       100.0             360.0        0.825444
# 4                0.0        78.0             360.0        1.000000
#
#    Property_Area
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Ahmad\AppData\Local\Temp\ipykernel_12808\3466773781.py:5: SyntaxWarning: invalid escape sequence '\S'
#   df = pd.read_csv("D:\Skillify Zone Intern\Task no 04\Loan Prediction.csv")
